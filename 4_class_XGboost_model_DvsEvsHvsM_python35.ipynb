# %%
# @hidden_cell
# The project token is an authorization token that is used to access project resources like data sources, connections, and used by platform APIs.
from project_lib import Project
project = Project(project_id='0173f8a1-9364-4a93-85fd-5a49de9c53f1', project_access_token='p-8c8d4ebd62e185973357f8daf6fe46662979370c')
pc = project.project_context

# %% [markdown]
# # 1. Set up the environment
#
# Before running the code in this notebook, please make sure you have the following requirements:
#
# A Watson Machine Learning (WML) Service instance (a free plan is offered and information about how to create an instance can be found here)
#
# 1. Local python environment configurations:
# - Python 3.5
# - xgboost
# - watson-machine-learning-client
# - pixiedust
# - matplotlib
# - seaborn
#
# 2. Download the Grape leaves dataset.

# %% [markdown]
# # 2. Load and explore the data
#
# In this section, we will load the data into a pandas dataframe and perform an exploratory data analysis (EDA).

# %%
# !rm -Rf datasetWS_DvsEvsHvsM_512-512_git

# %%
# !git clone https://github.com/RenataUjhaziova/datasetWS_DvsEvsHvsM_512-512_git.git
# Out:
# Cloning into 'datasetWS_DvsEvsHvsM_512-512_git'...
# remote: Enumerating objects: 292, done.
# remote: Counting objects: 100% (292/292), done.
# remote: Compressing objects: 100% (290/290), done.
# remote: Total 292 (delta 0), reused 289 (delta 0), pack-reused 0
# Receiving objects: 100% (292/292), 49.26 MiB | 46.91 MiB/s, done.

# %%
# !ls
# Out:
# datasetWS_DvsEvsHvsM_512-512_git

# %%
# %cd ./datasetWS_DvsEvsHvsM_512-512_git/
# Out:
# /home/dsxuser/work/datasetWS_DvsEvsHvsM_512-512_git

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (4.1.0.25)
# Requirement already satisfied: numpy>=1.11.1 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from opencv-python) (1.13.3)
# tensorflow 1.3.0 requires tensorflow-tensorboard<0.2.0,>=0.1.0, which is not installed.

# %%
# Get the data.
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# read images
def read_images(path):
    print('Reading from', path)
    files = [file for file in os.listdir(path)]
    image = cv2.imread(path+files[0])
    images = np.zeros(shape=(len(files), 512, 512, image.shape[2]))
    for i in range(len(files)):
        image = cv2.imread(path+files[i])
        images[i,:,:,:] = cv2.resize(image,(512,512))
    return images

# %%
healthy_train = read_images(path= '../datasetWS_DvsEvsHvsM_512-512_git/training_set/healthy/')
esca_train = read_images(path= '../datasetWS_DvsEvsHvsM_512-512_git/training_set/esca/')
dry_train = read_images(path= '../datasetWS_DvsEvsHvsM_512-512_git/training_set/dry/')
mite_train = read_images(path= '../datasetWS_DvsEvsHvsM_512-512_git/training_set/mite/')
# Out:
# Reading from ../datasetWS_DvsEvsHvsM_512-512_git/training_set/healthy/
# Reading from ../datasetWS_DvsEvsHvsM_512-512_git/training_set/esca/
# Reading from ../datasetWS_DvsEvsHvsM_512-512_git/training_set/dry/
# Reading from ../datasetWS_DvsEvsHvsM_512-512_git/training_set/mite/

# %%
healthy_test = read_images(path= '../datasetWS_DvsEvsHvsM_512-512_git/test_set/healthy/')
esca_test = read_images(path= '../datasetWS_DvsEvsHvsM_512-512_git/test_set/esca/')
dry_test = read_images(path= '../datasetWS_DvsEvsHvsM_512-512_git/test_set/dry/')
mite_test = read_images(path= '../datasetWS_DvsEvsHvsM_512-512_git/test_set/mite/')
# Out:
# Reading from ../datasetWS_DvsEvsHvsM_512-512_git/test_set/healthy/
# Reading from ../datasetWS_DvsEvsHvsM_512-512_git/test_set/esca/
# Reading from ../datasetWS_DvsEvsHvsM_512-512_git/test_set/dry/
# Reading from ../datasetWS_DvsEvsHvsM_512-512_git/test_set/mite/

# %%
# record count in each classes
plt.figure(0)
plt.bar(['dry', 'esca', 'healthy', 'mite'],\
        [healthy_train.shape[0] + healthy_test.shape[0],
         esca_train.shape[0] + esca_test.shape[0], 
         dry_train.shape[0] + dry_test.shape[0], 
         mite_train.shape[0] + mite_test.shape[0]])
plt.show()

# %%
# create dataframe
import pandas as pd

# %%
data = pd.DataFrame(columns=['hist_data', 'label'])
def append_to_df(img_array, df, label):
    for image in img_array:
        hist_b = np.histogram(image[:,:,0], bins=30, density=True, range=(0,255))[0]
        hist_g = np.histogram(image[:,:,1], bins=30, density=True, range=(0,255))[0]
        hist_r = np.histogram(image[:,:,2], bins=30, density=True, range=(0,255))[0]
        hist = np.append(np.append(hist_r, hist_g), hist_b)
        df = df.append({'hist_data': hist, 'label': label}, ignore_index=True)
    return df

# %%
data = append_to_df(dry_train, data,0)
data = append_to_df(dry_test, data,0)
data = append_to_df(esca_train, data,1)
data = append_to_df(esca_test, data,1)
data = append_to_df(healthy_train, data,2)
data = append_to_df(healthy_test, data,2)
data = append_to_df(mite_train, data,3)
data = append_to_df(mite_test, data,3)

# %%
data.head(10)
# Out:
#                                            hist_data label
# 0  [4.48787913603e-07, 5.38545496324e-06, 0.00015...     0
# 1  [0.000143163344439, 0.00142400404986, 0.002645...     0
# 2  [4.48787913603e-07, 4.12884880515e-05, 0.00093...     0
# 3  [3.14151539522e-06, 1.43612132353e-05, 0.00011...     0
# 4  [0.000175027286305, 0.00113947251264, 0.002285...     0
# 5  [4.48787913603e-06, 5.02642463235e-05, 0.00053...     0
# 6  [1.34636374081e-06, 1.07709099265e-05, 0.00069...     0
# 7  [8.07818244485e-06, 3.41078814338e-05, 0.00015...     0
# 8  [8.52697035846e-06, 4.30836397059e-05, 0.00058...     0
# 9  [0.0, 1.79515165441e-06, 2.3785759421e-05, 0.0...     0

# %%
# creating variables and labes
X = np.stack(data['hist_data'].values)
y = data['label'].values.astype(int)

# %%
# splitting the dataset into the Training and Testing set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.25, random_state = 0)

# List the number of records in each data set.
print('Number of training records: ' + str(len(X_train)))
print('Number of testing records : ' + str(len(X_test)))
# Out:
# Number of training records: 186
# Number of testing records : 62

# %% [markdown]
# # 3. Train the model

# %%
# Import packages you need to create the XGBoost model.
from xgboost.sklearn import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
# Out:
# /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
# Create the XGB classifier - xgb_model.
xgb_model = XGBClassifier(n_estimators=200, 
                          objective= 'multi:softmax')

# %%
# List the default parameters.
print(xgb_model.get_xgb_params())
# Out:
# {'missing': None, 'colsample_bytree': 1, 'colsample_bylevel': 1, 'max_delta_step': 0, 'objective': 'multi:softmax', 'base_score': 0.5, 'learning_rate': 0.1, 'reg_lambda': 1, 'subsample': 1, 'n_estimators': 200, 'reg_alpha': 0, 'min_child_weight': 1, 'silent': 1, 'max_depth': 3, 'scale_pos_weight': 1, 'gamma': 0, 'seed': 0}

# %%
# Train and evaluate.
xgb_model.fit(X_train, y_train, eval_metric=['mlogloss'], 
              eval_set=[((X_train, y_train)),(X_test, y_test)])
# Out:
# [0]	validation_0-mlogloss:1.24189	validation_1-mlogloss:1.28666
# [1]	validation_0-mlogloss:1.11657	validation_1-mlogloss:1.19932
# [2]	validation_0-mlogloss:1.00868	validation_1-mlogloss:1.12259
# [3]	validation_0-mlogloss:0.917018	validation_1-mlogloss:1.06072
# [4]	validation_0-mlogloss:0.835359	validation_1-mlogloss:0.999907
# [5]	validation_0-mlogloss:0.76351	validation_1-mlogloss:0.948516
# [6]	validation_0-mlogloss:0.700604	validation_1-mlogloss:0.898613
# [7]	validation_0-mlogloss:0.640666	validation_1-mlogloss:0.857841
# [8]	validation_0-mlogloss:0.589405	validation_1-mlogloss:0.817956
# [9]	validation_0-mlogloss:0.541673	validation_1-mlogloss:0.7821
# [10]	validation_0-mlogloss:0.500344	validation_1-mlogloss:0.749752
# [11]	validation_0-mlogloss:0.463164	validation_1-mlogloss:0.72781
# [12]	validation_0-mlogloss:0.427563	validation_1-mlogloss:0.705393
# [13]	validation_0-mlogloss:0.396146	validation_1-mlogloss:0.684758
# [14]	validation_0-mlogloss:0.368055	validation_1-mlogloss:0.658013
# [15]	validation_0-mlogloss:0.340513	validation_1-mlogloss:0.638137
# [16]	validation_0-mlogloss:0.31714	validation_1-mlogloss:0.616556
# [17]	validation_0-mlogloss:0.294184	validation_1-mlogloss:0.598445
# [18]	validation_0-mlogloss:0.273739	validation_1-mlogloss:0.581134
# [19]	validation_0-mlogloss:0.255331	validation_1-mlogloss:0.568538
# [20]	validation_0-mlogloss:0.238028	validation_1-mlogloss:0.555173
# [21]	validation_0-mlogloss:0.221601	validation_1-mlogloss:0.544335
# [22]	validation_0-mlogloss:0.207825	validation_1-mlogloss:0.533963
# [23]	validation_0-mlogloss:0.194811	validation_1-mlogloss:0.525224
# [24]	validation_0-mlogloss:0.182538	validation_1-mlogloss:0.514258
# [25]	validation_0-mlogloss:0.171424	validation_1-mlogloss:0.50595
# [26]	validation_0-mlogloss:0.161219	validation_1-mlogloss:0.498695
# [27]	validation_0-mlogloss:0.151675	validation_1-mlogloss:0.488531
# [28]	validation_0-mlogloss:0.14234	validation_1-mlogloss:0.478867
# [29]	validation_0-mlogloss:0.134229	validation_1-mlogloss:0.472814
# [30]	validation_0-mlogloss:0.126602	validation_1-mlogloss:0.462779
# [31]	validation_0-mlogloss:0.119238	validation_1-mlogloss:0.456921
# [32]	validation_0-mlogloss:0.112824	validation_1-mlogloss:0.450059
# [33]	validation_0-mlogloss:0.106828	validation_1-mlogloss:0.444565
# [34]	validation_0-mlogloss:0.10109	validation_1-mlogloss:0.43863
# [35]	validation_0-mlogloss:0.095715	validation_1-mlogloss:0.435672
# [36]	validation_0-mlogloss:0.090978	validation_1-mlogloss:0.431931
# [37]	validation_0-mlogloss:0.086719	validation_1-mlogloss:0.428813
# [38]	validation_0-mlogloss:0.082443	validation_1-mlogloss:0.426071
# [39]	validation_0-mlogloss:0.078496	validation_1-mlogloss:0.423696
# [40]	validation_0-mlogloss:0.074763	validation_1-mlogloss:0.419823
# [41]	validation_0-mlogloss:0.071375	validation_1-mlogloss:0.420711
# [42]	validation_0-mlogloss:0.068134	validation_1-mlogloss:0.418275
# [43]	validation_0-mlogloss:0.065191	validation_1-mlogloss:0.415945
# [44]	validation_0-mlogloss:0.06263	validation_1-mlogloss:0.412653
# [45]	validation_0-mlogloss:0.059888	validation_1-mlogloss:0.409865
# [46]	validation_0-mlogloss:0.057611	validation_1-mlogloss:0.409904
# [47]	validation_0-mlogloss:0.055434	validation_1-mlogloss:0.410978
# [48]	validation_0-mlogloss:0.053199	validation_1-mlogloss:0.408322
# [49]	validation_0-mlogloss:0.051259	validation_1-mlogloss:0.404939
# [50]	validation_0-mlogloss:0.049343	validation_1-mlogloss:0.403312
# [51]	validation_0-mlogloss:0.047605	validation_1-mlogloss:0.402083
# [52]	validation_0-mlogloss:0.045718	validation_1-mlogloss:0.400629
# [53]	validation_0-mlogloss:0.044075	validation_1-mlogloss:0.399943
# [54]	validation_0-mlogloss:0.042574	validation_1-mlogloss:0.400553
# [55]	validation_0-mlogloss:0.041119	validation_1-mlogloss:0.39909
# [56]	validation_0-mlogloss:0.039936	validation_1-mlogloss:0.397309
# [57]	validation_0-mlogloss:0.038628	validation_1-mlogloss:0.396903
# [58]	validation_0-mlogloss:0.037482	validation_1-mlogloss:0.395546
# [59]	validation_0-mlogloss:0.036337	validation_1-mlogloss:0.396685
# [60]	validation_0-mlogloss:0.035336	validation_1-mlogloss:0.396093
# [61]	validation_0-mlogloss:0.034218	validation_1-mlogloss:0.394762
# [62]	validation_0-mlogloss:0.033376	validation_1-mlogloss:0.394487
# [63]	validation_0-mlogloss:0.032446	validation_1-mlogloss:0.393486
# [64]	validation_0-mlogloss:0.031696	validation_1-mlogloss:0.392331
# [65]	validation_0-mlogloss:0.030916	validation_1-mlogloss:0.392885
# [66]	validation_0-mlogloss:0.03016	validation_1-mlogloss:0.393071
# [67]	validation_0-mlogloss:0.029361	validation_1-mlogloss:0.392393
# [68]	validation_0-mlogloss:0.028732	validation_1-mlogloss:0.390569
# [69]	validation_0-mlogloss:0.028158	validation_1-mlogloss:0.389326
# [70]	validation_0-mlogloss:0.027443	validation_1-mlogloss:0.389144
# [71]	validation_0-mlogloss:0.026856	validation_1-mlogloss:0.387895
# [72]	validation_0-mlogloss:0.026284	validation_1-mlogloss:0.387245
# [73]	validation_0-mlogloss:0.025803	validation_1-mlogloss:0.388541
# [74]	validation_0-mlogloss:0.02536	validation_1-mlogloss:0.388116
# [75]	validation_0-mlogloss:0.024864	validation_1-mlogloss:0.387948
# [76]	validation_0-mlogloss:0.02442	validation_1-mlogloss:0.386048
# [77]	validation_0-mlogloss:0.024022	validation_1-mlogloss:0.386241
# [78]	validation_0-mlogloss:0.023658	validation_1-mlogloss:0.38641
# [79]	validation_0-mlogloss:0.023339	validation_1-mlogloss:0.38567
# [80]	validation_0-mlogloss:0.022991	validation_1-mlogloss:0.386048
# [81]	validation_0-mlogloss:0.022652	validation_1-mlogloss:0.385913
# [82]	validation_0-mlogloss:0.022321	validation_1-mlogloss:0.385995
# [83]	validation_0-mlogloss:0.022036	validation_1-mlogloss:0.385503
# [84]	validation_0-mlogloss:0.021639	validation_1-mlogloss:0.386687
# [85]	validation_0-mlogloss:0.021381	validation_1-mlogloss:0.386944
# [86]	validation_0-mlogloss:0.021052	validation_1-mlogloss:0.387056
# [87]	validation_0-mlogloss:0.020815	validation_1-mlogloss:0.386908
# [88]	validation_0-mlogloss:0.02048	validation_1-mlogloss:0.38684
# [89]	validation_0-mlogloss:0.020236	validation_1-mlogloss:0.38633
# [90]	validation_0-mlogloss:0.019989	validation_1-mlogloss:0.386069
# [91]	validation_0-mlogloss:0.019763	validation_1-mlogloss:0.386094
# [92]	validation_0-mlogloss:0.019518	validation_1-mlogloss:0.386117
# [93]	validation_0-mlogloss:0.01927	validation_1-mlogloss:0.385253
# [94]	validation_0-mlogloss:0.019053	validation_1-mlogloss:0.385531
# [95]	validation_0-mlogloss:0.018829	validation_1-mlogloss:0.385085
# [96]	validation_0-mlogloss:0.018621	validation_1-mlogloss:0.384746
# [97]	validation_0-mlogloss:0.018375	validation_1-mlogloss:0.383988
# [98]	validation_0-mlogloss:0.01819	validation_1-mlogloss:0.384069
# [99]	validation_0-mlogloss:0.018002	validation_1-mlogloss:0.382989
# [100]	validation_0-mlogloss:0.017831	validation_1-mlogloss:0.381846
# [101]	validation_0-mlogloss:0.017648	validation_1-mlogloss:0.382052
# [102]	validation_0-mlogloss:0.017508	validation_1-mlogloss:0.382577
# [103]	validation_0-mlogloss:0.017363	validation_1-mlogloss:0.382002
# [104]	validation_0-mlogloss:0.017228	validation_1-mlogloss:0.382561
# [105]	validation_0-mlogloss:0.017115	validation_1-mlogloss:0.382445
# [106]	validation_0-mlogloss:0.016966	validation_1-mlogloss:0.381867
# [107]	validation_0-mlogloss:0.016856	validation_1-mlogloss:0.382047
# [108]	validation_0-mlogloss:0.016743	validation_1-mlogloss:0.381102
# [109]	validation_0-mlogloss:0.016645	validation_1-mlogloss:0.381264
# [110]	validation_0-mlogloss:0.016537	validation_1-mlogloss:0.380896
# [111]	validation_0-mlogloss:0.016439	validation_1-mlogloss:0.380329
# [112]	validation_0-mlogloss:0.016337	validation_1-mlogloss:0.380256
# [113]	validation_0-mlogloss:0.016232	validation_1-mlogloss:0.380237
# [114]	validation_0-mlogloss:0.016141	validation_1-mlogloss:0.379595
# [115]	validation_0-mlogloss:0.01605	validation_1-mlogloss:0.379451
# [116]	validation_0-mlogloss:0.015954	validation_1-mlogloss:0.379248
# [117]	validation_0-mlogloss:0.015855	validation_1-mlogloss:0.378582
# [118]	validation_0-mlogloss:0.01576	validation_1-mlogloss:0.378959
# [119]	validation_0-mlogloss:0.015674	validation_1-mlogloss:0.378952
# [120]	validation_0-mlogloss:0.015586	validation_1-mlogloss:0.378253
# [121]	validation_0-mlogloss:0.015527	validation_1-mlogloss:0.378589
# [122]	validation_0-mlogloss:0.015434	validation_1-mlogloss:0.378845
# [123]	validation_0-mlogloss:0.015376	validation_1-mlogloss:0.378843
# [124]	validation_0-mlogloss:0.015295	validation_1-mlogloss:0.379033
# [125]	validation_0-mlogloss:0.015215	validation_1-mlogloss:0.377761
# [126]	validation_0-mlogloss:0.015127	validation_1-mlogloss:0.377488
# [127]	validation_0-mlogloss:0.01505	validation_1-mlogloss:0.376706
# [128]	validation_0-mlogloss:0.014969	validation_1-mlogloss:0.376913
# [129]	validation_0-mlogloss:0.014895	validation_1-mlogloss:0.376888
# [130]	validation_0-mlogloss:0.01482	validation_1-mlogloss:0.375671
# [131]	validation_0-mlogloss:0.014766	validation_1-mlogloss:0.375771
# [132]	validation_0-mlogloss:0.014683	validation_1-mlogloss:0.375269
# [133]	validation_0-mlogloss:0.014631	validation_1-mlogloss:0.375341
# [134]	validation_0-mlogloss:0.01456	validation_1-mlogloss:0.375557
# [135]	validation_0-mlogloss:0.014492	validation_1-mlogloss:0.37467
# [136]	validation_0-mlogloss:0.014441	validation_1-mlogloss:0.374754
# [137]	validation_0-mlogloss:0.014375	validation_1-mlogloss:0.373771
# [138]	validation_0-mlogloss:0.014326	validation_1-mlogloss:0.374101
# [139]	validation_0-mlogloss:0.014261	validation_1-mlogloss:0.374427
# [140]	validation_0-mlogloss:0.01419	validation_1-mlogloss:0.374877
# [141]	validation_0-mlogloss:0.014115	validation_1-mlogloss:0.374566
# [142]	validation_0-mlogloss:0.014066	validation_1-mlogloss:0.374055
# [143]	validation_0-mlogloss:0.013998	validation_1-mlogloss:0.374018
# [144]	validation_0-mlogloss:0.01394	validation_1-mlogloss:0.374065
# [145]	validation_0-mlogloss:0.013894	validation_1-mlogloss:0.373435
# [146]	validation_0-mlogloss:0.013821	validation_1-mlogloss:0.373642
# [147]	validation_0-mlogloss:0.013775	validation_1-mlogloss:0.373319
# [148]	validation_0-mlogloss:0.01372	validation_1-mlogloss:0.372829
# [149]	validation_0-mlogloss:0.013675	validation_1-mlogloss:0.372679
# [150]	validation_0-mlogloss:0.013611	validation_1-mlogloss:0.372483
# [151]	validation_0-mlogloss:0.013567	validation_1-mlogloss:0.37276
# [152]	validation_0-mlogloss:0.013503	validation_1-mlogloss:0.37239
# [153]	validation_0-mlogloss:0.01346	validation_1-mlogloss:0.372037
# [154]	validation_0-mlogloss:0.013417	validation_1-mlogloss:0.371976
# [155]	validation_0-mlogloss:0.013374	validation_1-mlogloss:0.371428
# [156]	validation_0-mlogloss:0.013313	validation_1-mlogloss:0.371292
# [157]	validation_0-mlogloss:0.013271	validation_1-mlogloss:0.371084
# [158]	validation_0-mlogloss:0.013229	validation_1-mlogloss:0.371094
# [159]	validation_0-mlogloss:0.013188	validation_1-mlogloss:0.371568
# [160]	validation_0-mlogloss:0.013129	validation_1-mlogloss:0.370777
# [161]	validation_0-mlogloss:0.013088	validation_1-mlogloss:0.370834
# [162]	validation_0-mlogloss:0.013048	validation_1-mlogloss:0.370894
# [163]	validation_0-mlogloss:0.013008	validation_1-mlogloss:0.370044
# [164]	validation_0-mlogloss:0.012968	validation_1-mlogloss:0.370661
# [165]	validation_0-mlogloss:0.012929	validation_1-mlogloss:0.370499
# [166]	validation_0-mlogloss:0.012891	validation_1-mlogloss:0.370777
# [167]	validation_0-mlogloss:0.012852	validation_1-mlogloss:0.370026
# [168]	validation_0-mlogloss:0.012814	validation_1-mlogloss:0.370486
# [169]	validation_0-mlogloss:0.012776	validation_1-mlogloss:0.370272
# [170]	validation_0-mlogloss:0.012738	validation_1-mlogloss:0.36983
# [171]	validation_0-mlogloss:0.012686	validation_1-mlogloss:0.369553
# [172]	validation_0-mlogloss:0.012649	validation_1-mlogloss:0.369616
# [173]	validation_0-mlogloss:0.012613	validation_1-mlogloss:0.369986
# [174]	validation_0-mlogloss:0.012577	validation_1-mlogloss:0.370233
# [175]	validation_0-mlogloss:0.012541	validation_1-mlogloss:0.370688
# [176]	validation_0-mlogloss:0.012506	validation_1-mlogloss:0.369817
# [177]	validation_0-mlogloss:0.012472	validation_1-mlogloss:0.37016
# [178]	validation_0-mlogloss:0.012437	validation_1-mlogloss:0.369508
# [179]	validation_0-mlogloss:0.012403	validation_1-mlogloss:0.369389
# [180]	validation_0-mlogloss:0.01237	validation_1-mlogloss:0.369673
# [181]	validation_0-mlogloss:0.012336	validation_1-mlogloss:0.369911
# [182]	validation_0-mlogloss:0.012303	validation_1-mlogloss:0.369855
# [183]	validation_0-mlogloss:0.012269	validation_1-mlogloss:0.369437
# [184]	validation_0-mlogloss:0.012237	validation_1-mlogloss:0.369974
# [185]	validation_0-mlogloss:0.012202	validation_1-mlogloss:0.369582
# [186]	validation_0-mlogloss:0.01217	validation_1-mlogloss:0.36956
# [187]	validation_0-mlogloss:0.012139	validation_1-mlogloss:0.368891
# [188]	validation_0-mlogloss:0.012108	validation_1-mlogloss:0.369422
# [189]	validation_0-mlogloss:0.012077	validation_1-mlogloss:0.36938
# [190]	validation_0-mlogloss:0.012047	validation_1-mlogloss:0.369816
# [191]	validation_0-mlogloss:0.012016	validation_1-mlogloss:0.369172
# [192]	validation_0-mlogloss:0.011986	validation_1-mlogloss:0.369597
# [193]	validation_0-mlogloss:0.011957	validation_1-mlogloss:0.369324
# [194]	validation_0-mlogloss:0.011928	validation_1-mlogloss:0.369312
# [195]	validation_0-mlogloss:0.011899	validation_1-mlogloss:0.369185
# [196]	validation_0-mlogloss:0.01187	validation_1-mlogloss:0.369644
# [197]	validation_0-mlogloss:0.011842	validation_1-mlogloss:0.369327
# [198]	validation_0-mlogloss:0.011814	validation_1-mlogloss:0.369274
# [199]	validation_0-mlogloss:0.011787	validation_1-mlogloss:0.368914
# XGBClassifier(base_score=0.5, colsample_bylevel=1, colsample_bytree=1,
#        gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=3,
#        min_child_weight=1, missing=None, n_estimators=200, nthread=-1,
#        objective='multi:softprob', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=0, silent=True, subsample=1)

# %%
# Plot and display the performance evaluation
xgb_eval = xgb_model.evals_result()
# eval_steps = range(len(xgb_eval['validation_0']['merror']))
eval_steps = range(len(xgb_eval['validation_0']['mlogloss']))

# %%
fig, ax = plt.subplots(1, 1, sharex=True, figsize=(8, 6))

ax.plot(eval_steps, [1-x for x in xgb_eval['validation_0']['mlogloss']], label='Train')
ax.plot(eval_steps, [1-x for x in xgb_eval['validation_1']['mlogloss']], label='Test')
ax.legend()
ax.set_title('Accuracy')
ax.set_xlabel('Number of iterations')
# Out:
# Text(0.5,0,'Number of iterations')

# %%
# Select trained model.
n_trees = 85
y_pred = xgb_model.predict(X_test, ntree_limit= n_trees)

# %%
# Check the accuracy of the trained model.
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy: %.2f%%' % (accuracy * 100.0))
# Out:
# Accuracy: 85.48%

# %% [markdown]
# Note: You will use the test data accuracy to compare the accuracy of the model with default parameters to the accuracy of the model with tuned parameters.

# %%
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(y_test, y_pred)
plt.matshow(cm)
plt.colorbar()
plt.xlabel('Actual values')
plt.ylabel('Predicted values')
plt.show()
pd.DataFrame(cm)
# Out:
#     0   1   2   3
# 0  11   0   0   0
# 1   2  13   0   2
# 2   0   0  17   1
# 3   0   3   1  12

# %%
# prediction
y_pred_prob = xgb_model.predict_proba(X_test)
y_pred_prob
# Out:
# array([[  1.93020201e-03,   3.69880050e-02,   8.58483851e-01,
#           1.02597959e-01],
#        [  1.24701504e-02,   8.29893723e-03,   7.96203554e-01,
#           1.83027357e-01],
#        [  2.14108569e-03,   9.83320832e-01,   2.97778123e-03,
#           1.15602752e-02],
#        [  8.70375137e-04,   3.34930024e-04,   9.93185282e-01,
#           5.60938893e-03],
#        [  5.90513635e-04,   6.34565076e-04,   9.82738554e-01,
#           1.60363633e-02],
#        [  4.08312231e-02,   4.15034950e-01,   3.76170538e-02,
#           5.06516755e-01],
#        [  9.92611229e-01,   9.64583887e-04,   7.87644356e-04,
#           5.63649973e-03],
#        [  2.97568142e-02,   1.23521779e-02,   9.42629397e-01,
#           1.52616352e-02],
#        [  3.35009396e-02,   5.96696258e-01,   2.72058606e-01,
#           9.77442041e-02],
#        [  8.38246197e-03,   5.69616705e-02,   1.91588610e-01,
#           7.43067265e-01],
#        [  1.06594164e-03,   9.97611165e-01,   6.36938785e-04,
#           6.85909996e-04],
#        [  8.23399751e-04,   2.14222958e-03,   1.66120485e-03,
#           9.95373189e-01],
#        [  8.67879950e-03,   4.75489199e-01,   4.23530519e-01,
#           9.23014879e-02],
#        [  8.51405668e-04,   6.07420458e-04,   9.81740713e-01,
#           1.68004651e-02],
#        [  1.36393448e-03,   2.73158262e-03,   8.91101897e-01,
#           1.04802556e-01],
#        [  3.94965056e-03,   4.05971985e-03,   1.33597190e-02,
#           9.78630900e-01],
#        [  9.96033251e-01,   9.04933491e-04,   1.00817450e-03,
#           2.05362216e-03],
#        [  2.59830430e-03,   9.92005885e-01,   3.43079539e-03,
#           1.96507736e-03],
#        [  5.86069189e-04,   3.39909159e-02,   2.57773697e-03,
#           9.62845206e-01],
#        [  6.99528903e-02,   4.12038743e-01,   2.17919499e-01,
#           3.00088882e-01],
#        [  6.98606309e-04,   8.51043407e-03,   1.71713613e-03,
#           9.89073813e-01],
#        [  7.03835802e-04,   3.98170814e-04,   9.97473061e-01,
#           1.42494065e-03],
#        [  1.97287455e-01,   6.07770756e-02,   6.89361453e-01,
#           5.25740124e-02],
#        [  1.48996676e-03,   9.86127496e-01,   1.02884844e-02,
#           2.09408533e-03],
#        [  9.58077431e-01,   9.17560514e-03,   9.47591662e-03,
#           2.32710708e-02],
#        [  9.86558944e-03,   7.55740702e-01,   1.44117316e-02,
#           2.19981954e-01],
#        [  9.25217867e-01,   4.79300469e-02,   1.62198935e-02,
#           1.06321992e-02],
#        [  2.02073855e-03,   9.78691638e-01,   2.03820807e-03,
#           1.72493514e-02],
#        [  9.33052242e-01,   1.04837222e-02,   1.44958617e-02,
#           4.19682339e-02],
#        [  1.30580366e-03,   9.91310716e-01,   6.51653390e-03,
#           8.66966147e-04],
#        [  2.81882356e-03,   9.40430403e-01,   5.73517988e-03,
#           5.10155670e-02],
#        [  9.87294495e-01,   5.59645845e-03,   3.71518615e-03,
#           3.39389942e-03],
#        [  2.82105850e-03,   1.26218917e-02,   2.86928028e-01,
#           6.97629035e-01],
#        [  5.80913387e-02,   9.20096159e-01,   9.63104516e-03,
#           1.21813966e-02],
#        [  5.72082936e-04,   3.60903505e-04,   9.96203005e-01,
#           2.86402460e-03],
#        [  9.93047535e-01,   2.88746599e-03,   3.97317635e-04,
#           3.66769568e-03],
#        [  9.97121394e-01,   5.58204891e-04,   6.40588056e-04,
#           1.67975633e-03],
#        [  1.99585110e-02,   3.90723580e-03,   4.58472550e-01,
#           5.17661691e-01],
#        [  9.85877037e-01,   9.95682459e-03,   6.69641013e-04,
#           3.49644595e-03],
#        [  6.38844795e-04,   1.97665766e-02,   9.75344896e-01,
#           4.24972503e-03],
#        [  5.01909666e-03,   4.65230457e-03,   1.49502605e-03,
#           9.88833547e-01],
#        [  1.41857862e-02,   9.50157940e-01,   5.12960460e-03,
#           3.05267014e-02],
#        [  8.35989229e-03,   9.90088940e-01,   3.44830129e-04,
#           1.20635459e-03],
#        [  2.20145267e-02,   3.36795556e-03,   9.62209523e-01,
#           1.24080200e-02],
#        [  8.03590228e-04,   9.98051524e-01,   5.07923367e-04,
#           6.36929472e-04],
#        [  1.34018585e-02,   3.18891294e-02,   8.47439229e-01,
#           1.07269734e-01],
#        [  2.74522789e-03,   1.11900764e-02,   2.86511362e-01,
#           6.99553311e-01],
#        [  4.74529108e-04,   5.06361574e-03,   9.93421495e-01,
#           1.04034389e-03],
#        [  9.08324838e-01,   7.92953074e-02,   2.83709704e-03,
#           9.54270363e-03],
#        [  1.12149278e-02,   3.22767310e-02,   2.88664307e-02,
#           9.27641869e-01],
#        [  1.77010172e-03,   9.92447257e-01,   9.35336866e-04,
#           4.84733004e-03],
#        [  9.94753003e-01,   9.03996173e-04,   1.53791509e-03,
#           2.80502695e-03],
#        [  5.56783343e-04,   1.50260702e-03,   2.88606482e-03,
#           9.95054483e-01],
#        [  9.77262497e-01,   1.64045226e-02,   3.40611627e-03,
#           2.92684231e-03],
#        [  1.24852185e-03,   9.97593820e-01,   3.31746327e-04,
#           8.25861876e-04],
#        [  9.96320605e-01,   1.51010789e-03,   9.91414068e-04,
#           1.17781630e-03],
#        [  6.39533857e-03,   4.72310930e-03,   3.07829343e-02,
#           9.58098590e-01],
#        [  9.15022625e-04,   4.01907339e-04,   9.96194720e-01,
#           2.48834165e-03],
#        [  1.38065265e-02,   4.05499153e-02,   9.03777897e-01,
#           4.18656692e-02],
#        [  2.60333437e-03,   7.97045883e-03,   9.75822806e-01,
#           1.36034535e-02],
#        [  1.57446563e-02,   1.15310512e-02,   4.66468278e-03,
#           9.68059599e-01],
#        [  6.76991593e-04,   3.48619360e-04,   9.98014331e-01,
#           9.60017613e-04]], dtype=float32)

# %% [markdown]
# ## 3.1 Grid search and cross validation for model tuning

# %% [markdown]
# Use grid search and cross-validation to tune the model.

# %%
# Create XGBoost pipeline, set up parameter grid.
xgb_model_gs = XGBClassifier()
parameters = {'reg_alpha': [0.0, 1.0, 2.0], 
              'reg_lambda': [0.0, 1.0, 2.0], 
              'n_estimators': [n_trees], 
              'seed': [1337]}

# %%
# Search for the best parameters.
clf = GridSearchCV(estimator = xgb_model_gs, 
                   param_grid = parameters, scoring='accuracy', 
                   cv=5, verbose=1, n_jobs=1, refit=True)
clf.fit(X_train, y_train)

# %%
# View the performance result.
clf.grid_scores_

# %% [markdown]
# Display the accuracy estimated using cross-validation and the hyperparameter values for the best model.

# %%
print('Best score: %.1f%%' % (clf.best_score_*100))
print('Best parameter set: %s' % (clf.best_params_))

# %%
# Display the accuracy of the best parameter combination on the test set.
y_pred = clf.best_estimator_.predict(X_test, ntree_limit= n_trees)

# %%
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy: %.2f%%' % (accuracy * 100.0))

# %% [markdown]
# ## 3.2 PCA for model tuning

# %% [markdown]
# Use PCA to tune the model.

# %%
# PCA
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=10)
xgb_model_pca = XGBClassifier(n_estimators=n_trees)
pipeline = Pipeline(steps=[('pca', pca), ('xgb', xgb_model_pca)])

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('pca', PCA(copy=True, iterated_power='auto', n_components=10, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)), ('xgb', XGBClassifier(base_score=0.5, colsample_bylevel=1, colsample_bytree=1,
#        gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=3,
#        min_child_weight=1, missing=None, n_estimators=85, nthread=-1,
#        objective='multi:softprob', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=0, silent=True, subsample=1))])

# %% [markdown]
# You are ready to evaluate the accuracy of the model trained on the reduced set of features.

# %%
y_pred = pipeline.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy: %.2f%%' % (accuracy * 100.0))
# Out:
# Accuracy: 88.71%

# %% [markdown]
# # 4. Persist the model
#
# In this section, we will show how to use the watson-machine-learning-client package to store your XGBoost model in the WML repository.

# %%
# !rm -rf $PIP_BUILD/watson-machine-learning-client

# %%
# !pip install watson-machine-learning-client
# Out:
# Requirement already satisfied: watson-machine-learning-client in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (1.0.371)
# Requirement already satisfied: urllib3 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from watson-machine-learning-client) (1.22)
# Requirement already satisfied: ibm-cos-sdk in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from watson-machine-learning-client) (2.0.1)
# Requirement already satisfied: certifi in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from watson-machine-learning-client) (2019.6.16)
# Requirement already satisfied: requests in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from watson-machine-learning-client) (2.18.4)
# Requirement already satisfied: tabulate in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from watson-machine-learning-client) (0.8.2)
# Requirement already satisfied: tqdm in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from watson-machine-learning-client) (4.19.5)
# Requirement already satisfied: lomond in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from watson-machine-learning-client) (0.1.13)
# Requirement already satisfied: pandas in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from watson-machine-learning-client) (0.21.0)
# Requirement already satisfied: ibm-cos-sdk-s3transfer==2.*,>=2.0.0 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from ibm-cos-sdk->watson-machine-learning-client) (2.0.1)
# Requirement already satisfied: ibm-cos-sdk-core==2.*,>=2.0.0 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from ibm-cos-sdk->watson-machine-learning-client) (2.0.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from requests->watson-machine-learning-client) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from requests->watson-machine-learning-client) (2.6)
# Requirement already satisfied: six>=1.10.0 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from lomond->watson-machine-learning-client) (1.11.0)
# Requirement already satisfied: python-dateutil>=2 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from pandas->watson-machine-learning-client) (2.6.1)
# Requirement already satisfied: pytz>=2011k in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from pandas->watson-machine-learning-client) (2018.3)
# Requirement already satisfied: numpy>=1.9.0 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from pandas->watson-machine-learning-client) (1.13.3)
# Requirement already satisfied: docutils>=0.10 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from ibm-cos-sdk-core==2.*,>=2.0.0->ibm-cos-sdk->watson-machine-learning-client) (0.14)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /opt/conda/envs/DSX-Python35/lib/python3.5/site-packages (from ibm-cos-sdk-core==2.*,>=2.0.0->ibm-cos-sdk->watson-machine-learning-client) (0.9.3)
# tensorflow 1.3.0 requires tensorflow-tensorboard<0.2.0,>=0.1.0, which is not installed.

# %%
from watson_machine_learning_client import WatsonMachineLearningAPIClient

# %%
wml_credentials={
    'url': 'https://us-south.ml.cloud.ibm.com',
    'access_key': '1i_a51p0p4pg-wRnOy3XdLwHrxzURhXz2_dERELy_RR-',
    'username': '68c5e0c2-16df-4265-9846-3c382fd66494',
    'password': 'b696c9e3-d790-41c6-900d-580a64f9ccbb',
    'instance_id': '985d7680-d220-4984-85e1-31cf24cd3369'
}

# %%
client = WatsonMachineLearningAPIClient(wml_credentials)

# %% [markdown]
# # 5. Save the XGBoost model in the WML Repository

# %% [markdown]
# Save the model artifact as XGBoost model for image recognition to WML instance.

# %%
model_props = {client.repository.ModelMetaNames.NAME: 'XGBoost model for grape leaves disease classification'}
pipeline_xgb_model = Pipeline(steps=[('xgb', xgb_model)])
model_details = client.repository.store_model(pipeline, model_props)

# %%
print(model_details)
# Out:
# {'entity': {'deployments': {'url': 'https://us-south.ml.cloud.ibm.com/v3/wml_instances/985d7680-d220-4984-85e1-31cf24cd3369/published_models/1fd4a6c8-f228-4c6a-badb-3ff5d259d6e0/deployments', 'count': 0}, 'feedback_url': 'https://us-south.ml.cloud.ibm.com/v3/wml_instances/985d7680-d220-4984-85e1-31cf24cd3369/published_models/1fd4a6c8-f228-4c6a-badb-3ff5d259d6e0/feedback', 'runtime_environment': 'python-3.5', 'learning_configuration_url': 'https://us-south.ml.cloud.ibm.com/v3/wml_instances/985d7680-d220-4984-85e1-31cf24cd3369/published_models/1fd4a6c8-f228-4c6a-badb-3ff5d259d6e0/learning_configuration', 'latest_version': {'url': 'https://us-south.ml.cloud.ibm.com/v3/ml_assets/models/1fd4a6c8-f228-4c6a-badb-3ff5d259d6e0/versions/79679a0b-7e59-4063-a145-ea2648726b46', 'created_at': '2019-07-14T20:32:37.233Z', 'guid': '79679a0b-7e59-4063-a145-ea2648726b46'}, 'model_type': 'scikit-learn-0.19', 'name': 'XGBoost model for grape leaves disease classification', 'learning_iterations_url': 'https://us-south.ml.cloud.ibm.com/v3/wml_instances/985d7680-d220-4984-85e1-31cf24cd3369/published_models/1fd4a6c8-f228-4c6a-badb-3ff5d259d6e0/learning_iterations', 'evaluation_metrics_url': 'https://us-south.ml.cloud.ibm.com/v3/wml_instances/985d7680-d220-4984-85e1-31cf24cd3369/published_models/1fd4a6c8-f228-4c6a-badb-3ff5d259d6e0/evaluation_metrics'}, 'metadata': {'url': 'https://us-south.ml.cloud.ibm.com/v3/wml_instances/985d7680-d220-4984-85e1-31cf24cd3369/published_models/1fd4a6c8-f228-4c6a-badb-3ff5d259d6e0', 'created_at': '2019-07-14T20:32:37.160Z', 'modified_at': '2019-07-14T20:32:37.233Z', 'guid': '1fd4a6c8-f228-4c6a-badb-3ff5d259d6e0'}}

# %% [markdown]
# Get the saved model metadata from WML.

# %% [markdown]
# # 6. Deploy and score in the WML repository

# %% [markdown]
# In this section, you will learn how to create online scoring and score a new data record in the WML repository.
#
# You can list all stored models using the list_models method.

# %%
# Display a list of all the models.
client.repository.list_models()
# Out:
# ------------------------------------  ------------------------------------------------------------  ------------------------  -----------------
# GUID                                  NAME                                                          CREATED                   FRAMEWORK
# 1fd4a6c8-f228-4c6a-badb-3ff5d259d6e0  XGBoost model for grape leaves disease classification         2019-07-14T20:32:37.160Z  scikit-learn-0.19
# a414a079-bbad-41ee-b7eb-5b070bba674b  KNN model for grape leaves disease classification             2019-07-09T11:37:56.141Z  scikit-learn-0.19
# f79bb1c3-2ab2-46de-bf24-cf1cf74ccfd4  ANN cv model for grape leaves disease classification v1-1     2019-07-09T09:14:57.196Z  tensorflow-1.5
# fc015b39-38b7-4433-aa34-3e3dab3ffc9f  CNN model for grape leaves disease classification 128-128 v3  2019-07-06T16:19:53.753Z  tensorflow-1.5
# 24abf95f-9ef9-4bf4-af17-46c199f94828  CNN model for grape leaves disease classification v1          2019-06-30T12:28:01.218Z  tensorflow-1.5
# 1e538c7a-8582-4a29-b90d-0ce9e029550b  Birdsongs_ML_model2                                           2019-05-08T19:40:02.886Z  wml-1.1
# 9a7bb8a5-c303-49ca-9610-23764cdab2e3  BirdSongs_ML_models                                           2019-05-08T19:30:54.465Z  wml-1.1
# 3fdfc4fc-5d62-436c-99fd-f779adad9c55  Cats_and_Dogs_ML_model                                        2019-05-08T09:30:56.333Z  wml-1.1
# ------------------------------------  ------------------------------------------------------------  ------------------------  -----------------

# %% [markdown]
# You need the model uid to create the deployment. You can extract the model uid from the saved model details.

# %%
# Extract the uid.
model_uid = client.repository.get_model_uid(model_details)
print(model_uid)
# Out:
# 1fd4a6c8-f228-4c6a-badb-3ff5d259d6e0

# %% [markdown]
# Use this modul_uid in the next section to create the deployment.

# %% [markdown]
# ## 6.1 Create a model deployment

# %% [markdown]
# Now, you can create a deployment, and classify grape leaves diseases.

# %%
# Create the deployment.
deployment_details = client.deployments.create(model_uid, 'Predict grape leaves diseases')
# Out:
# #######################################################################################
#
# Synchronous deployment creation for uid: '1fd4a6c8-f228-4c6a-badb-3ff5d259d6e0' started
#
# #######################################################################################
#
#
# INITIALIZING
# DEPLOY_SUCCESS
#
#
# ------------------------------------------------------------------------------------------------
# Successfully finished deployment creation, deployment_uid='28d60649-d780-4c36-888f-326f7ff5deff'
# ------------------------------------------------------------------------------------------------

# %% [markdown]
# Get the list of all deployments.

# %%
# List the deployments.
client.deployments.list()
# Out:
# ------------------------------------  ----------------------------------------------------------  ------  --------------  ------------------------  -----------------  -------------
# GUID                                  NAME                                                        TYPE    STATE           CREATED                   FRAMEWORK          ARTIFACT TYPE
# 28d60649-d780-4c36-888f-326f7ff5deff  Predict grape leaves diseases                               online  DEPLOY_SUCCESS  2019-07-14T20:32:39.742Z  scikit-learn-0.19  model
# 77f737fc-8932-45bb-a991-b645fbc5e66b  Predict grape leaves diseases KNN                           online  DEPLOY_SUCCESS  2019-07-09T11:37:58.661Z  scikit-learn-0.19  model
# f9653920-f751-4726-847f-161b2099473e  Predict grape leaves diseases - ANN cv model final v1-1     online  DEPLOY_SUCCESS  2019-07-09T09:14:59.593Z  tensorflow-1.5     model
# f42ade46-aa26-4266-9028-1a52b01375ac  Predict grape leaves diseases - CNN model final 128-128 v3  online  DEPLOY_SUCCESS  2019-07-06T16:20:02.679Z  tensorflow-1.5     model
# c3374942-d0f1-477b-9cde-aff5055abab9  Predict grape leaves diseases - CNN model final v1          online  DEPLOY_SUCCESS  2019-06-30T12:28:48.611Z  tensorflow-1.5     model
# ------------------------------------  ----------------------------------------------------------  ------  --------------  ------------------------  -----------------  -------------

# %% [markdown]
# The Predict grape leaves diseases model has been successfully deployed.

# %% [markdown]
# ## 6.2 Perform prediction

# %% [markdown]
# Now, extract the url endpoint, scoring_url, which will be used to send scoring requests.

# %%
# Extract endpoint url and display it.
scoring_url = client.deployments.get_scoring_url(deployment_details)
print(scoring_url)
# Out:
# https://us-south.ml.cloud.ibm.com/v3/wml_instances/985d7680-d220-4984-85e1-31cf24cd3369/deployments/28d60649-d780-4c36-888f-326f7ff5deff/online

# %% [markdown]
# Prepare the scoring payload with the values to score.

# %%
# Prepare scoring payload.
#payload_scoring = {'values': [list(X_test[0]), list(X_test[1])]}
payload_scoring = {'values': [list(X_test[0]), list(X_test[1]), list(X_test[2])]}
print(payload_scoring)
# Out:
# {'values': [[8.9757582720588234e-07, 0.00013373879825367648, 0.0013014849494485295, 0.0035005457261029411, 0.0069898717543658085, 0.0081706327550551475, 0.010959849638097426, 0.010327956255744486, 0.0086575676413143381, 0.0062009026022518381, 0.0060492122874540441, 0.0046682918772977941, 0.0052723604090073525, 0.0049097397748161763, 0.0057386510512408085, 0.0048765294692095585, 0.0050950891831341915, 0.0037334666532628678, 0.0037514181698069852, 0.003044577205882353, 0.0035570930032169119, 0.0034619499655330881, 0.003570556640625, 0.0019028607536764705, 0.00090879552504595593, 0.00057489731732536769, 0.00024055032169117648, 4.1288488051470591e-05, 5.8342428768382349e-06, 4.4878791360294117e-07, 4.4878791360294117e-07, 0.00024952607996323527, 0.002227783203125, 0.0029871323529411763, 0.0041674445657169119, 0.0050457225126378678, 0.0064670338350183822, 0.0063691980698529415, 0.0094258925494025737, 0.0085862103630514712, 0.0073596729951746322, 0.0051561243393841915, 0.0054280898150275737, 0.0046808579388786763, 0.0052799898035386025, 0.0050928452435661763, 0.0054608513327205881, 0.0048662073471966915, 0.0051633049460018381, 0.0045691097483915441, 0.0043963264016544119, 0.0030342550838694852, 0.0024117862477022059, 0.0016291001263786765, 0.00418853759765625, 0.003081826602711397, 0.00028453153722426473, 3.410788143382353e-05, 2.243939568014706e-06, 8.9757582720588234e-07, 0.001228781307444853, 0.0098517922794117644, 0.025376712574678308, 0.019073486328125, 0.01397705078125, 0.0088061164407169119, 0.0072685690487132356, 0.0051821540383731619, 0.0049402573529411763, 0.003609152401194853, 0.0036280014935661763, 0.002556295955882353, 0.0020608340992647059, 0.0013418758616727941, 0.0010766422047334559, 0.00052912095013786769, 0.00035454245174632352, 0.00020958395565257352, 0.0001503439510569853, 0.00011848000919117647, 0.00012341667624080882, 0.0001243142520680147, 0.00027286305147058824, 0.00011668485753676471, 0.00013822667738970588, 0.0001503439510569853, 0.0005035400390625, 0.0045857149011948525, 0.00026747759650735297, 2.4683335248161765e-05], [2.6927274816176472e-06, 1.7502728630514705e-05, 0.00024997486787683824, 0.0021398207720588237, 0.00608062744140625, 0.0080885045668658093, 0.0085238288430606619, 0.0055793313419117644, 0.0050232831169577203, 0.0043155445772058822, 0.0053854549632352941, 0.0057408949908088237, 0.0069615981158088237, 0.006500244140625, 0.0079080918255974263, 0.0067389993106617644, 0.0071581672219669119, 0.0057956471162683822, 0.0058441162109375, 0.0050717522116268381, 0.0043002857881433822, 0.002655029296875, 0.0022035486557904411, 0.0015344058766084559, 0.0013131534352022059, 0.00074543672449448527, 0.00060631247127757352, 0.00038550881778492648, 0.00034287396599264703, 0.00043442670036764703, 0.0, 1.0322122012867648e-05, 6.7766974954044121e-05, 0.00032537123736213236, 0.0012552597943474265, 0.0018216301413143381, 0.0032694199505974263, 0.0042787439682904415, 0.0068888944738051475, 0.00611114501953125, 0.0059473374310661763, 0.0049178179572610297, 0.0042814366957720585, 0.0029193653779871322, 0.003387899959788603, 0.0036980124080882352, 0.0054936128504136025, 0.0056556252872242644, 0.0069059484145220585, 0.0063274607938878678, 0.0073300529928768381, 0.0070841172162224263, 0.0078641106100643381, 0.0062251371495863975, 0.0061304428998161763, 0.0040476181927849263, 0.0029274435604319852, 0.0014307358685661765, 0.00074319278492647055, 0.00030113669002757352, 0.0026913811178768381, 0.010822520536534926, 0.019554586971507353, 0.014579324161305147, 0.012426488539751838, 0.0095964319565716907, 0.0094743616440716907, 0.0078721887925091907, 0.0078546860638786763, 0.0059370153090533085, 0.0054388607249540441, 0.0036953196806066178, 0.0029552684110753678, 0.0017116771024816176, 0.0010936961454503676, 0.00050578397863051473, 0.00035903033088235297, 0.00021945728975183824, 0.00016650031594669118, 0.00012117273667279412, 0.00011713364545036765, 9.1552734375e-05, 9.200152228860294e-05, 7.7191521139705879e-05, 8.257697610294 ...

# %%
# Perform prediction and display the result.
import json
response_scoring = client.deployments.score(scoring_url, payload_scoring)
print(json.dumps(response_scoring, indent=3))
# Out:
# {
#    "values": [
#       [
#          3,
#          [
#             0.008622948080301285,
#             0.027669019997119904,
#             0.020941022783517838,
#             0.9427670240402222
#          ]
#       ],
#       [
#          2,
#          [
#             0.002432451816275716,
#             0.0032675580587238073,
#             0.5177907943725586,
#             0.476509153842926
#          ]
#       ],
#       [
#          1,
#          [
#             0.03635270148515701,
#             0.7915259599685669,
#             0.034164901822805405,
#             0.1379563957452774
#          ]
#       ]
#    ],
#    "fields": [
#       "prediction",
#       "probability"
#    ]
# }

# %% [markdown]
# Result of the classification: The selected grape leaves are classified as mite, healthy and esca.
